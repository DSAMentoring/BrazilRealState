# %%
import pandas as pd
import numpy as np

# %%
# dataset loading
df = pd.read_csv("properati-BR-2016-11-01-properties-sell.csv")

# %%
df.head()
# Out:
#    created_on operation property_type place_name  \
# 0  2013-04-25      sell     apartment   Mondubim
# 1  2013-04-25      sell         house   Manhuaçu
# 2  2013-04-25      sell         house    Ibatiba
# 3  2013-04-25      sell     apartment   Manhuaçu
# 4  2013-04-25      sell     apartment   Manhuaçu
#
#              place_with_parent_names  geonames_id lat-lon  lat  lon     price  \
# 0  |Brasil|Ceará|Fortaleza|Mondubim|          NaN     NaN  NaN  NaN  155900.0
# 1     |Brasil|Minas Gerais|Manhuaçu|          NaN     NaN  NaN  NaN  950000.0
# 2    |Brasil|Espírito Santo|Ibatiba|          NaN     NaN  NaN  NaN       NaN
# 3     |Brasil|Minas Gerais|Manhuaçu|          NaN     NaN  NaN  NaN       NaN
# 4     |Brasil|Minas Gerais|Manhuaçu|          NaN     NaN  NaN  NaN       NaN
#
#    ... surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 0  ...                   NaN               NaN           NaN    NaN    2.0
# 1  ...                   NaN               NaN           NaN    NaN    NaN
# 2  ...                   NaN               NaN           NaN    NaN    NaN
# 3  ...                   NaN               NaN           NaN    NaN    NaN
# 4  ...                   NaN               NaN           NaN    NaN    NaN
#
#    expenses                                      properati_url  \
# 0       NaN  http://mondubim.properati.com.br/px9_vende-se_...
# 1       NaN  http://manhuacu.properati.com.br/pxv_vende-se_...
# 2       NaN  http://ibatiba.properati.com.br/pxw_vende-se_o...
# 3       NaN  http://manhuacu.properati.com.br/pxy_vende-se_...
# 4       NaN  http://manhuacu.properati.com.br/pxz_vende-se_...
#
#                                          description  \
# 0  Otimo Imovel com o melhor valor da regiao, con...
# 1  Otimo Imovel com o melhor valor da regiao, con...
# 2  Otimo Imovel com o melhor valor da regiao, con...
# 3  Otimo Imovel com o melhor valor da regiao, con...
# 4  Otimo Imovel com o melhor valor da regiao, con...
#
#                       title                                    image_thumbnail
# 0  Apartamento Em Fortaleza  https://thumbs-cf.properati.com/8/EY670SQWML7c...
# 1          Casa Em Manhuacu  https://thumbs-cf.properati.com/1/1VGQees9LIbx...
# 2          Sítio Em Ibatiba                                                NaN
# 3   Apartamento Em Manhuacu                                                NaN
# 4   Apartamento Em Manhuacu  https://thumbs-cf.properati.com/2/UhPHI8dsNCb4...
#
# [5 rows x 24 columns]

# %%
# dataset dimension
df.shape
# Out:
# (872672, 24)

# %%
#number of missing values
missing_values = list(df.isnull().sum())

#attributes names
attributes = list(df.columns)

#columns names
columns = ["variable", "MissingValues"]

# %%
# create a dataframe to identify the percentage of missing values
df_percentage = pd.DataFrame(list(zip(attributes, missing_values)),
                            columns=columns)

#create the percentage column
df_percentage['percentage'] = (df_percentage['MissingValues']/df.shape[0])*100

# %%
df_percentage
# Out:
#                       variable  MissingValues  percentage
# 0                   created_on              0    0.000000
# 1                    operation              0    0.000000
# 2                property_type              0    0.000000
# 3                   place_name              0    0.000000
# 4      place_with_parent_names              0    0.000000
# 5                  geonames_id         872532   99.983957
# 6                      lat-lon         485445   55.627429
# 7                          lat         485445   55.627429
# 8                          lon         485445   55.627429
# 9                        price          53271    6.104355
# 10                    currency          53290    6.106533
# 11  price_aprox_local_currency          53271    6.104355
# 12             price_aprox_usd          53271    6.104355
# 13         surface_total_in_m2         655738   75.141405
# 14       surface_covered_in_m2         239432   27.436654
# 15            price_usd_per_m2         283491   32.485401
# 16                price_per_m2         283491   32.485401
# 17                       floor         821878   94.179486
# 18                       rooms         330926   37.921006
# 19                    expenses         639354   73.263953
# 20               properati_url              0    0.000000
# 21                 description              0    0.000000
# 22                       title              0    0.000000
# 23             image_thumbnail          38665    4.430645

# %%
#missing values
df.isnull().sum()
# Out:
# created_on                         0
# operation                          0
# property_type                      0
# place_name                         0
# place_with_parent_names            0
# geonames_id                   872532
# lat-lon                       485445
# lat                           485445
# lon                           485445
# price                          53271
# currency                       53290
# price_aprox_local_currency     53271
# price_aprox_usd                53271
# surface_total_in_m2           655738
# surface_covered_in_m2         239432
# price_usd_per_m2              283491
# price_per_m2                  283491
# floor                         821878
# rooms                         330926
# expenses                      639354
# properati_url                      0
# description                        0
# title                              0
# image_thumbnail                38665
# dtype: int64

# %%
df.tail(20)
# Out:
#         created_on operation property_type            place_name  \
# 872652  2016-10-31      sell         house           Santo André
# 872653  2016-10-31      sell         house           Santo André
# 872654  2016-10-31      sell     apartment             Campestre
# 872655  2016-10-31      sell     apartment  São José dos Pinhais
# 872656  2016-10-31      sell     apartment    São Caetano do Sul
# 872657  2016-10-31      sell     apartment              Olímpico
# 872658  2016-10-31      sell     apartment             Boqueirão
# 872659  2016-10-31      sell     apartment             Boqueirão
# 872660  2016-11-01      sell     apartment          Vila Formosa
# 872661  2016-11-01      sell         house              Urbanova
# 872662  2016-11-01      sell         house              Urbanova
# 872663  2016-11-01      sell         house    Araçoiaba da Serra
# 872664  2016-11-01      sell         house          Praia Grande
# 872665  2016-11-01      sell     apartment          Praia Grande
# 872666  2016-11-01      sell         house          Praia Grande
# 872667  2016-11-01      sell     apartment       Barra da Tijuca
# 872668  2016-11-01      sell     apartment              Itaquera
# 872669  2016-11-01      sell         house             São Paulo
# 872670  2016-11-01      sell         house               Vila Ré
# 872671  2016-11-01      sell         house          Vila Taquari
#
#                                   place_with_parent_names  geonames_id  \
# 872652                     |Brasil|São Paulo|Santo André|          NaN
# 872653                     |Brasil|São Paulo|Santo André|          NaN
# 872654           |Brasil|São Paulo|Santo André|Campestre|          NaN
# 872655               |Brasil|Paraná|São José dos Pinhais|          NaN
# 872656              |Brasil|São Paulo|São Caetano do Sul|          NaN
# 872657     |Brasil|São Paulo|São Caetano do Sul|Olímpico|          NaN
# 872658                 |Brasil|Paraná|Curitiba|Boqueirão|          NaN
# 872659                 |Brasil|Paraná|Curitiba|Boqueirão|          NaN
# 872660          |Brasil|São Paulo|São Paulo|Vila Formosa|          NaN
# 872661    |Brasil|São Paulo|São José dos Campos|Urbanova|          NaN
# 872662    |Brasil|São Paulo|São José dos Campos|Urbanova|          NaN
# 872663              |Brasil|São Paulo|Araçoiaba da Serra|          NaN
# 872664                    |Brasil|São Paulo|Praia Grande|          NaN
# 872665                    |Brasil|São Paulo|Praia Grande|          NaN
# 872666                    |Brasil|São Paulo|Praia Grande|          NaN
# 872667  |Brasil|Rio de Janeiro|Rio de Janeiro|Barra da...          NaN
# 872668              |Brasil|São Paulo|São Paulo|Itaquera|          NaN
# 872669                       |Brasil|São Paulo|São Paulo|          NaN
# 872670               |Brasil|São Paulo|São Paulo|Vila Ré|          NaN
# 872671          |Brasil|São Paulo|São Paulo|Vila Taquari|          NaN
#
#                         lat-lon        lat        lon      price  ...  \
# 872652                      NaN        NaN        NaN   690000.0  ...
# 872653                      NaN        NaN        NaN   585000.0  ...
# 872654                      NaN        NaN        NaN   479000.0  ...
# 872655  -25.5023025,-49.1632714 -25.502302 -49.163271   135000.0  ...
# 872656                      NaN        NaN        NaN   535000.0  ...
# 872657                      NaN        NaN        NaN   420000.0  ...
# 872658                      NaN        NaN        NaN   239000.0  ...
# 872659                      NaN        NaN        NaN   249000.0  ...
# 872660                      NaN        NaN        NaN   750000.0  ...
# 872661                      NaN        NaN        NaN   750000.0  ...
# 872662                      NaN        NaN        NaN   590000.0  ...
# 872663                      NaN        NaN        NaN   640000.0  ...
# 872664                      NaN        NaN        NaN   145000.0  ...
# 872665                      NaN        NaN        NaN   135000.0  ...
# 872666                      NaN        NaN        NaN   260000.0  ...
# 872667    -23.009399,-43.317394 -23.009399 -43.317394  2200000.0  ...
# 872668                      NaN        NaN        NaN   210000.0  ...
# 872669                      NaN        NaN        NaN   480000.0  ...
# 872670                      NaN        NaN        NaN   600000.0  ...
# 872671                      NaN        NaN        NaN   370000.0  ...
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 872652                 240.0        897.147833   2875.000000    NaN    1.0
# 872653                 113.0       1615.487434   5176.991150    NaN    1.0
# 872654                  74.0       2019.900405   6472.972973    NaN    1.0
# 872655                   NaN               NaN           NaN    NaN    1.0
# 872656                  75.0       2225.966800   7133.333333    NaN    1.0
# 872657                  69.0       1899.443333   6086.956522    NaN    1.0
# 872658                  65.0       1147.389077   3676.923077    NaN    1.0
# 872659                  65.0       1195.396923   3830.769231    NaN    2.0
# 872660                 130.0       1800.296615   5769.230769    NaN    2.0
# 872661                   NaN               NaN           NaN    NaN    NaN
# 872662                   NaN               NaN           NaN    NaN    NaN
# 872663                 224.0        891.575491   2857.142857    NaN    2.0
# 872664                   NaN               NaN           NaN    NaN    1.0
# 872665                   NaN               NaN           NaN    NaN    NaN
# 872666                   NaN               NaN           NaN    NaN    1.0
# 872667                 105.0       6538.220286  20952.380952    NaN    2.0
# 872668                  58.0       1129.841207   3620.689655    NaN    1.0
# 872669                 270.0        554.758074   1777.777778    NaN    2.0
# 872670                 110.0       1702.098636   5454.545455    NaN    1.0
# 872671                 165.0        699.751636   2242.424242    NaN    1.0
#
#         expenses                                      properati_url  \
# 872652       NaN  http://santo-andre-sao-paulo.properati.com.br/...
# 872653       NaN  http://santo-andre-sao-paulo.properati.com.br/...
# 872654     300.0  http://campestre-santo-andre1.properati.com.br...
# 872655       NaN  http://sao-jose-dos-pinhais-parana.properati.c...
# 872656     409.0  http://sao-caetano-do-sul.properati.com.br/2hk...
# 872657     550.0  http://olimpico.properati.com.br/2hk03_venda_a...
# 872658       NaN  http://boqueirao-curitiba.properati.com.br/2hk...
# 872659       NaN  http://boqueirao-curitiba.properati.com.br/2hk...
# 872660       NaN  http://vila-formosa.properati.com.br/2hk07_ven...
# 872661       NaN  http://urbanova.properati.com.br/2hk08_venda_c...
# 872662       NaN  http://urbanova.properati.com.br/2hk09_venda_c...
# 872663     250.0  http://aracoiaba-da-serra.properati.com.br/2hk...
# 872664       NaN  http://praia-grande-sao-paulo.properati.com.br...
# 872665       NaN  http://praia-grande-sao-paulo.properati.com.br...
# 872666       NaN  http://praia-grande-sao-paulo.properati.com.br...
# 872667    2450.0  http://barra-da-tijuca.properati.com.br/2hk0i_...
# 872668     300.0  http://itaquera.properati.com.br/2hk0k_venda_a...
# 872669       NaN  http://sao-paulo.properati.com.br/2hk0l_venda_...
# 872670       NaN  http://vila-re.properati.com.br/2hk0m_venda_ca...
# 872671       NaN  http://vila-taquari.properati.com.br/2hk0n_ven...
#
#                                               description  \
# 872652  Ótimo Sobrado - Vila Floresta - Santo André. Á...
# 872653  Lindo Sobrado - Novíssimo - Pronto para morar ...
# 872654  Apartamento - Jardim - Com sala ampla, 03 dorm...
# 872655  OPORTUNIDADE Apartamento com dois quartos, sal...
# 872656  Apartamento Novo - São Caetano do Sul - Bairro...
# 872657  Oportunidade!!! Excelente Apartamento - Ótima ...
# 872658  Residencial Quebec, pronto para morar! Apartam...
# 872659  Residencial Quebec, pronto para morar! Apartam...
# 872660  Apartamento residencial à venda, Vila Formosa,...
# 872661  Linda casa térrea com 4 dormitórios, sendo 3 s...
# 872662  Sobrado no Urbanova com 3 suítes planejadas, s...
# 872663  Excelente casa térrea no Condomínio Village Ip...
# 872664  Casa Geminada - 2 dormitórios, garagem para 2 ...
# 872665  Apartamento de 1 dormitório e 1 vaga de garage...
# 872666  Linda casa geminada nova no Maracanã em Praia ...
